# %% [markdown]
# # FizzBuzz

# %% [markdown]
# ###### https://imranontech.com/2007/01/24/using-fizzbuzz-to-find-developers-who-grok-coding/

# %% [markdown]
# ### Imprima os números de 0 a 100, porém:
#
# * Sempre que o número for múltiplo de 3, substitua por Fizz.
# * Sempre que o número for múltiplo de , substitua por Buzz.
# * Quando for múltiplo de ambos, substitua por FizzBuzz.

# %% [markdown]
# ## Ex: 1 - Bugado

# %%
for i in range(1, 101):
    if i%3 == 0:
        print('Fizz')
    if i%5 == 0:
        print('Buzz')
    if i%3 != 0 and i%5 != 0:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# Fizz
# Buzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# Fizz
# Buzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# Fizz
# Buzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# Fizz
# Buzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# Fizz
# Buzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# Fizz
# Buzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# ## Ex: 2 - Ainda Bugado

# %%
for i in range(1, 101):
    if i%3 == 0:
        print('Fizz')
    if i%5 == 0:
        print('Buzz')
    if i%3 == 0 and i%5 == 0:
        print('FizzBuzz')
    if i%3 != 0 and i%5 != 0:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# Fizz
# Buzz
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# Fizz
# Buzz
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# Fizz
# Buzz
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# Fizz
# Buzz
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# Fizz
# Buzz
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# Fizz
# Buzz
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# ## Ex: 3 - Complicado

# %%
for i in range(1, 101):
    if i%3 == 0 and i%5 != 0:
        print('Fizz')
    if i%5 == 0 and i%3 != 0:
        print('Buzz')
    if i%3 == 0 and i%5 == 0:
        print('FizzBuzz')
    if i%3 != 0 and i%5 != 0:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# ## Ex: 4 - Simples

# %%
for i in range(1, 101):
    if i%3 == 0 and i%5 == 0:
        print('FizzBuzz')
    elif i%3 == 0:
        print('Fizz')
    elif i%5 == 0:
        print('Buzz')
    else:
        print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# Mas eu vou ter que sempre ficar repetindo os testes?

# %% [markdown]
# ## Ex: 5 - Sem Repetição de Teste

# %%
for i in range(1, 101):
    mod3 = i%3 == 0
    mod5 = i%5 == 0
    if mod3 != mod5:
        print('FizzBuzz')
    elif mod3:
        print('Fizz')
    elif mod5:
        print('Buzz')
    else:
        print(i)

# %% [markdown]
# Agora ta bom, mas se eu quiser mudar os valores 3 e 5 para outros números como 7 e 8. Eu tenho que me lembrar de alterar cade pedaço do código onde esses números aparecem.
# Sem contar que o teste para saber se é multiplo de 5 ou de 3 é feito duas vezes.

# %% [markdown]
# ## Ex: 6 - Simples Sem Repetição de Teste

# %%
for i in range(1, 101):
    output = ''
    if i%3 == 0:
        output += 'Fizz'
    if i%5 == 0:
        output += 'Buzz'
    if output == '':
        output += str(i)
    print(output)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# Agora o escalonamento e alterações estão mais fáceis, adicionando apenas mais um if, sem alterar mais nada do código, ele consegue tratar outros valores.

# %%
for i in range(1, 101):
    output = ''
    if i%3 == 0:
        output += 'Fizz'
    if i%2 == 0:
        output += 'Otto'
    if i%5 == 0:
        output += 'Buzz'
    if i%4 == 0:
        output += 'Gram'
    if output == '':
        output += str(i)
    print(output)
# Out:
# 1
# Otto
# Fizz
# OttoGram
# Buzz
# FizzOtto
# 7
# OttoGram
# Fizz
# OttoBuzz
# 11
# FizzOttoGram
# 13
# Otto
# FizzBuzz
# OttoGram
# 17
# FizzOtto
# 19
# OttoBuzzGram
# Fizz
# Otto
# 23
# FizzOttoGram
# Buzz
# Otto
# Fizz
# OttoGram
# 29
# FizzOttoBuzz
# 31
# OttoGram
# Fizz
# Otto
# Buzz
# FizzOttoGram
# 37
# Otto
# Fizz
# OttoBuzzGram
# 41
# FizzOtto
# 43
# OttoGram
# FizzBuzz
# Otto
# 47
# FizzOttoGram
# 49
# OttoBuzz
# Fizz
# OttoGram
# 53
# FizzOtto
# Buzz
# OttoGram
# Fizz
# Otto
# 59
# FizzOttoBuzzGram
# 61
# Otto
# Fizz
# OttoGram
# Buzz
# FizzOtto
# 67
# OttoGram
# Fizz
# OttoBuzz
# 71
# FizzOttoGram
# 73
# Otto
# FizzBuzz
# OttoGram
# 77
# FizzOtto
# 79
# OttoBuzzGram
# Fizz
# Otto
# 83
# FizzOttoGram
# Buzz
# Otto
# Fizz
# OttoGram
# 89
# FizzOttoBuzz
# 91
# OttoGram
# Fizz
# Otto
# Buzz
# FizzOttoGram
# 97
# Otto
# Fizz
# OttoBuzzGram

# %% [markdown]
# Mas ainda pode ser argumentado que os testes são os mesmos, eu estou sempre testando se o número X é múltiplo da contagem atual.

# %% [markdown]
# ## Ex: 7 - Simples Melhorado

# %%
for i in range(1, 101):
    output = ''
    if not i%3:
        output += 'Fizz'
    if not i%5:
        output += 'Buzz'
    print(output or i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# ## Ex: 8 - 1 Linha com concatenação de String

# %%
for i in range(1,101): print("Fizz"*(i%3==0) + "Buzz"*(i%5==0) or i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# ## Ex: 9

# %%
for i in range(1, 101):print(i%3//2*'Fizz'+i%5//4*'Buzz'or i)
# Out:
# 1
# Fizz
# 3
# Buzz
# Fizz
# 6
# 7
# Fizz
# Buzz
# 10
# Fizz
# 12
# 13
# FizzBuzz
# 15
# 16
# Fizz
# 18
# Buzz
# Fizz
# 21
# 22
# Fizz
# Buzz
# 25
# Fizz
# 27
# 28
# FizzBuzz
# 30
# 31
# Fizz
# 33
# Buzz
# Fizz
# 36
# 37
# Fizz
# Buzz
# 40
# Fizz
# 42
# 43
# FizzBuzz
# 45
# 46
# Fizz
# 48
# Buzz
# Fizz
# 51
# 52
# Fizz
# Buzz
# 55
# Fizz
# 57
# 58
# FizzBuzz
# 60
# 61
# Fizz
# 63
# Buzz
# Fizz
# 66
# 67
# Fizz
# Buzz
# 70
# Fizz
# 72
# 73
# FizzBuzz
# 75
# 76
# Fizz
# 78
# Buzz
# Fizz
# 81
# 82
# Fizz
# Buzz
# 85
# Fizz
# 87
# 88
# FizzBuzz
# 90
# 91
# Fizz
# 93
# Buzz
# Fizz
# 96
# 97
# Fizz
# Buzz
# 100

# %% [markdown]
# ## Ex: 10 - List Comprehension

# %%
for n in range(1, 101):
    fb = ''.join([ denom[1] if n % denom[0] == 0 else '' for denom in [(3,'fizz'),(5,'buzz')] ])
    print(fb if fb else n)
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizzbuzz
# 16
# 17
# fizz
# 19
# buzz
# fizz
# 22
# 23
# fizz
# buzz
# 26
# fizz
# 28
# 29
# fizzbuzz
# 31
# 32
# fizz
# 34
# buzz
# fizz
# 37
# 38
# fizz
# buzz
# 41
# fizz
# 43
# 44
# fizzbuzz
# 46
# 47
# fizz
# 49
# buzz
# fizz
# 52
# 53
# fizz
# buzz
# 56
# fizz
# 58
# 59
# fizzbuzz
# 61
# 62
# fizz
# 64
# buzz
# fizz
# 67
# 68
# fizz
# buzz
# 71
# fizz
# 73
# 74
# fizzbuzz
# 76
# 77
# fizz
# 79
# buzz
# fizz
# 82
# 83
# fizz
# buzz
# 86
# fizz
# 88
# 89
# fizzbuzz
# 91
# 92
# fizz
# 94
# buzz
# fizz
# 97
# 98
# fizz
# buzz

# %% [markdown]
# ## Ex: 11 - List Comprehension 2

# %%
print('\n'.join([(x%3<1)*'Fizz'+(x%5<1)*'Buzz' or str(x) for x in range(1,101)]))
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# ## Ex: 12 - Lazily

# %%
from itertools import count, cycle, islice
 
 
# fizzBuzz :: () -> Generator [String]
def fizzBuzz():
    '''A non-finite stream of fizzbuzz terms.'''
    return map(
        lambda f, b, n: (f + b) or n,
        cycle([''] * 2 + ['Fizz']),
        cycle([''] * 4 + ['Buzz']),
        map(str, count(1))
    )
 
 
# main :: IO ()
def main():
    '''Display of first 100 terms of the fizzbuzz series.
    '''
    print(unlines(
        take(100)(
            fizzBuzz()
        )
    ))
 
 
# GENERIC -------------------------------------------------
 
# take :: Int -> [a] -> [a]
# take :: Int -> String -> String
def take(n):
    '''The prefix of xs of length n,
       or xs itself if n > length xs.
    '''
    return lambda xs: (
        xs[0:n]
        if isinstance(xs, (list, tuple))
        else list(islice(xs, n))
    )
 
 
# unlines :: [String] -> String
def unlines(xs):
    '''A single string formed by the intercalation
       of a list of strings with the newline character.
    '''
    return '\n'.join(xs)
 
 
if __name__ == '__main__':
    main()
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz

# %% [markdown]
# ## Ex: 13 - Math

# %% [markdown]
# #### Números que terminam com 5 ou 0 são divisíveis por 5. Números cujos digitos recursivamente se somam a 3, 6 ou 9 são divisíveis por 3.

# %%
def numsum(n):
	''' The recursive sum of all digits in a number 
        unit a single character is obtained'''
	res = sum([int(i) for i in str(n)])
	if res < 10: return res
	else : return numsum(res)
 
for n in range(1,101):
	response = 'Fizz'*(numsum(n) in [3,6,9]) + \
                   'Buzz'*(str(n)[-1] in ['5','0'])\
	            or n
	print(response)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz
