# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Carregar os dados

# %%
import pandas as pd

path = 'Data/Acessos_Banda_Larga_Fixa_2019-2020.csv'
dados = pd.read_csv(path, sep=';')

# %%
dados.head()
# Out:
#     Ano  Mês Grupo Econômico                                     Empresa  \
# 0  2020    3          OUTROS  Brisanet Servicos de Telecomunicacoes Ltda
# 1  2020    3          OUTROS                 BRASCONECT INFORMATICA LTDA
# 2  2020    3          OUTROS                 BRASCONECT INFORMATICA LTDA
# 3  2020    3          OUTROS        BRAWNET COMERCIO E SERVIÇOS LTDA  ME
# 4  2020    3          OUTROS        BRAWNET COMERCIO E SERVIÇOS LTDA  ME
#
#        CNPJ Porte da Prestadora  UF            Município  \
# 0  4,60E+12       Pequeno Porte  RN  Coronel João Pessoa
# 1  8,63E+12       Pequeno Porte  MG          Piranguinho
# 2  8,63E+12       Pequeno Porte  MG           Brazópolis
# 3  1,44E+13       Pequeno Porte  BA            Barreiras
# 4  1,44E+13       Pequeno Porte  BA            Barreiras
#
#    Código IBGE Município Faixa de Velocidade Tecnologia Meio de Acesso  \
# 0                2402907      2Mbps a 12Mbps      Wi-Fi          Rádio
# ...

# %% [markdown]
# ### Colunas

# %%
dados.columns
# Out:
# Index(['Ano', 'Mês', 'Grupo Econômico', 'Empresa', 'CNPJ',
#        'Porte da Prestadora', 'UF', 'Município', 'Código IBGE Município',
#        'Faixa de Velocidade', 'Tecnologia', 'Meio de Acesso', 'Acessos'],
#       dtype='object')

# %% [markdown]
# ### NaN

# %%
dados.isnull().values.any()
#dados.dropna()
# Out:
# False

# %%
dados_pb = dados.loc(:, (dados['UF'] == 'PB') & (dados['Município'] == 'João Pessoa'))
dados_pb.head()
# Out:
#        Ano  Mês Grupo Econômico                           Empresa      CNPJ  \
# 1606  2020    3            CABO                              CABO  2,95E+12
# 2722  2020    3          OUTROS  BR27 SERVIÇOS DE TECNOLOGIA LTDA  1,26E+13
# 2728  2020    3          OUTROS  BR27 SERVIÇOS DE TECNOLOGIA LTDA  1,26E+13
# 2743  2020    3          OUTROS  BR27 SERVIÇOS DE TECNOLOGIA LTDA  1,26E+13
# 2764  2020    3          OUTROS  BR27 SERVIÇOS DE TECNOLOGIA LTDA  1,26E+13
#
#      Porte da Prestadora  UF    Município  Código IBGE Município  \
# 1606       Pequeno Porte  PB  João Pessoa                2507507
# 2722       Pequeno Porte  PB  João Pessoa                2507507
# 2728       Pequeno Porte  PB  João Pessoa                2507507
# 2743       Pequeno Porte  PB  João Pessoa                2507507
# 2764       Pequeno Porte  PB  João Pessoa                2507507
#
#      Faixa de Velocidade Tecnologia   Meio de Acesso  Acessos
# ...

# %%
dados_pb.drop(['Grupo Econômico', 'CNPJ', 'Código IBGE Município', 'Meio de Acesso'], axis=1, inplace=True)
# Out:
# C:\Users\bryan\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
dados_pb['Acessos'].hist()

# %%
empresas_pb = dados_pb.groupby(['Empresa'])
empresas_pb.head()
# Out:
#           Ano  Mês Grupo Econômico                                 Empresa  \
# 1606     2020    3            CABO                                    CABO
# 2722     2020    3          OUTROS        BR27 SERVIÇOS DE TECNOLOGIA LTDA
# 2728     2020    3          OUTROS        BR27 SERVIÇOS DE TECNOLOGIA LTDA
# 2743     2020    3          OUTROS        BR27 SERVIÇOS DE TECNOLOGIA LTDA
# 2764     2020    3          OUTROS        BR27 SERVIÇOS DE TECNOLOGIA LTDA
# ...       ...  ...             ...                                     ...
# 881767   2019   10          OUTROS  FORTEL FORTALEZA TELECOMUNICAÇÕES LTDA
# 898864   2019   10          OUTROS  ANNY RAYMARY NUNES BAZILIO 09705170410
# 921783   2019    9          OUTROS                 DDL LINE TELECOM EIRELI
# 1003924  2019    9          OUTROS             NEIDE BONNER RODRIGUES - ME
# 1004046  2019    9          OUTROS             NEIDE BONNER RODRIGUES - ME
#
# ...
